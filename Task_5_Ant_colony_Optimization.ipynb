# %% [markdown]
# <a href="https://colab.research.google.com/github/Manohar13C/AIT_LAB_TASKS/blob/main/Task_5_Ant_colony_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
R1 = float(input("Enter pheromone value R1: "))
R2 = float(input("Enter pheromone value R2: "))

total = R1 + R2

P1 = R1 / total
P2 = R2 / total

print("Probability of Path 1 =", P1)
print("Probability of Path 2 =", P2)

if P1 > P2:
    print("Ant prefers Path 1")
elif P2 > P1:
    print("Ant prefers Path 2")
else:
    print("Both paths have equal probability")

print("P1 + P2 =", P1 + P2)
# Out:
# Enter pheromone value R1: 67
# Enter pheromone value R2: 87
# Probability of Path 1 = 0.43506493506493504
# Probability of Path 2 = 0.564935064935065
# Ant prefers Path 2
# P1 + P2 = 1.0
